# %% [markdown]
# # Dictionaries

# %%
mydict = {'a':23}
mydict
# Out:
# {'a': 23}

# %%
empty_dict = {}
empty_dict
# Out:
# {}

# %%
empty_dict = dict()
empty_dict
# Out:
# {}

# %%
Student={'name':'kirab','age':23,'grade':'A+'}
Student
# Out:
# {'name': 'kirab', 'age': 23, 'grade': 'A+'}

# %%
for each in Student : // if we print the elements it will print the keys
    print(each)
# Out:
# name
# age
# grade

# %%
Student['grade'] # access dictionry element
# Out:
# 'A+'

# %%
Student.get('grade')
# Out:
# 'A+'

# %%
print(Student.get('last_name'))
# Out:
# None

# %%
print(Student.get('last_name',"NA")) # along with default value ifnot ounf
# Out:
# NA

# %%
## Dictionaries are mutable we can update and murate/update

# %%
## Dicrionary Methods

# %%
keys = Student.keys()
keys
# Out:
# dict_keys(['name', 'age', 'grade'])
